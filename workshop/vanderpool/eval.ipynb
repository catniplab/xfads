# %%
import os
import sys

import matplotlib.pyplot as plt
from hydra import compose, initialize

import math
import torch
import torch.nn as nn

import pytorch_lightning as lightning
from pytorch_lightning.loggers import CSVLogger
from pytorch_lightning.callbacks import ModelCheckpoint 

import xfads.utils as utils
import xfads.plot_utils as plot_utils

from xfads.ssm_modules.dynamics import DenseGaussianDynamics
from xfads.ssm_modules.likelihoods import GaussianLikelihood
from xfads.smoothers.lightning_trainers import LightningNonlinearSSM
from xfads.ssm_modules.dynamics import DenseGaussianInitialCondition
from xfads.ssm_modules.encoders import LocalEncoderLRMvn, BackwardEncoderLRMvn
from xfads.smoothers.nonlinear_smoother_causal import NonlinearFilter, LowRankNonlinearStateSpaceModel

# %%
torch.cuda.empty_cache()

# %%
"""config"""

initialize(version_base=None, config_path="", job_name="lds")
cfg = compose(config_name="config")

lightning.seed_everything(cfg.seed, workers=True)
torch.set_default_dtype(torch.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 """config"""
# ----> 3 initialize(version_base=None, config_path="", job_name="lds")
#       4 cfg = compose(config_name="config")
#       6 lightning.seed_everything(cfg.seed, workers=True)
#
# File /opt/anaconda3/envs/xfads/lib/python3.10/site-packages/hydra/initialize.py:91, in initialize.__init__(self, config_path, job_name, caller_stack_depth, version_base)
#      86 if job_name is None:
#      87     job_name = detect_task_name(
#      88         calling_file=calling_file, calling_module=calling_module
#      89     )
# ---> 91 Hydra.create_main_hydra_file_or_module(
#      92     calling_file=calling_file,
#      93     calling_module=calling_module,
#      94     config_path=config_path,
#      95     job_name=job_name,
#      96 )
#
# File /opt/anaconda3/envs/xfads/lib/python3.10/site-packages/hydra/_internal/hydra.py:53, in Hydra.create_main_hydra_file_or_module(cls, calling_file, calling_module, config_path, job_name)
#      41 @classmethod
#      42 def create_main_hydra_file_or_module(
#      43     cls: Type["Hydra"],
#    (...)
#      47     job_name: str,
#      48 ) -> "Hydra":
#      49     config_search_path = create_automatic_config_search_path(
#      50         calling_file, calling_module, config_path
#      51     )
# ---> 53     return Hydra.create_main_hydra2(job_name, config_search_path)
#
# File /opt/anaconda3/envs/xfads/lib/python3.10/site-packages/hydra/_internal/hydra.py:68, in Hydra.create_main_hydra2(cls, task_name, config_search_path)
#      65 hydra = cls(task_name=task_name, config_loader=config_loader)
#      66 from hydra.core.global_hydra import GlobalHydra
# ---> 68 GlobalHydra.instance().initialize(hydra)
#      69 return hydra
#
# File /opt/anaconda3/envs/xfads/lib/python3.10/site-packages/hydra/core/global_hydra.py:16, in GlobalHydra.initialize(self, hydra)
#      14 assert isinstance(hydra, Hydra), f"Unexpected Hydra type : {type(hydra)}"
#      15 if self.is_initialized():
# ---> 16     raise ValueError(
#      17         "GlobalHydra is already initialized, call GlobalHydra.instance().clear() if you want to re-initialize"
#      18     )
#      19 self.hydra = hydra
#
# ValueError: GlobalHydra is already initialized, call GlobalHydra.instance().clear() if you want to re-initialize

# %%
"""generate data -- 2d oscillator with decay"""

n_trials = 500
n_neurons = 100
n_time_bins = 250

mean_fn = utils.VdpDynamicsModel()

C = utils.FanInLinear(cfg.n_latents, n_neurons, device=cfg.device).requires_grad_(False)
Q_diag = 1e-2 * torch.ones(cfg.n_latents, device=cfg.device)
Q_0_diag = torch.ones(cfg.n_latents, device=cfg.device)
R_diag = 1e-1 * torch.ones(n_neurons, device=cfg.device)
m_0 = torch.zeros(cfg.n_latents, device=cfg.device)

z = utils.sample_gauss_z(mean_fn, Q_diag, m_0, Q_0_diag, n_trials, n_time_bins)
y = C(z) + torch.sqrt(R_diag) * torch.randn((n_trials, n_time_bins, n_neurons), device=cfg.device)
y = y.detach()

# %%
y_train, z_train = y[:n_trials//2], z[:n_trials//2]
y_valid, z_valid = y[n_trials//2:], z[n_trials//2:]

y_train_dataset = torch.utils.data.TensorDataset(y_train,)
y_valid_dataset = torch.utils.data.TensorDataset(y_valid,)

train_dataloader = torch.utils.data.DataLoader(
    y_train_dataset,
    batch_size=cfg.batch_sz,
    shuffle=True
)
valid_dataloader = torch.utils.data.DataLoader(
    y_valid_dataset,
    batch_size=cfg.batch_sz,
    shuffle=True
)

# %%
"""likelihood pdf"""

likelihood_pdf = GaussianLikelihood(C, n_neurons, R_diag, device=cfg.device)

# %%
"""dynamics module"""

dynamics_fn = utils.build_gru_dynamics_function(cfg.n_latents, cfg.n_hidden_dynamics, device=cfg.device)
dynamics_mod = DenseGaussianDynamics(dynamics_fn, cfg.n_latents, Q_diag, device=cfg.device)

# %%
"""initial condition"""
initial_condition_pdf = DenseGaussianInitialCondition(cfg.n_latents, m_0, Q_0_diag, device=cfg.device)

# %%
"""local/backward encoder"""

backward_encoder = BackwardEncoderLRMvn(cfg.n_latents, cfg.n_hidden_backward, cfg.n_latents,
                                        rank_local=cfg.rank_local, rank_backward=cfg.rank_backward,
                                        device=cfg.device)

local_encoder = LocalEncoderLRMvn(cfg.n_latents, n_neurons, cfg.n_hidden_local, cfg.n_latents, rank=cfg.rank_local,
                                  device=cfg.device, dropout=cfg.p_local_dropout)

# %%
nl_filter = NonlinearFilter(dynamics_mod, initial_condition_pdf, device=cfg.device)

# %%
"""sequence vae"""

ssm = LowRankNonlinearStateSpaceModel(dynamics_mod, likelihood_pdf, initial_condition_pdf, backward_encoder,
                                      local_encoder, nl_filter, device=cfg.device)

# %%
"""lightning"""

seq_vae = LightningNonlinearSSM.load_from_checkpoint(torch.load(f'ckpts/best_model_path.pt'), ssm=ssm, cfg=cfg)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[58], line 3
#       1 """lightning"""
# ----> 3 seq_vae = LightningNonlinearSSM.load_from_checkpoint(torch.load(f'ckpts/best_model_path.pt'), ssm=ssm, cfg=cfg)
#
# File /opt/anaconda3/envs/xfads/lib/python3.10/site-packages/pytorch_lightning/utilities/model_helpers.py:125, in _restricted_classmethod_impl.__get__.<locals>.wrapper(*args, **kwargs)
#     120 if instance is not None and not is_scripting:
#     121     raise TypeError(
#     122         f"The classmethod `{cls.__name__}.{self.method.__name__}` cannot be called on an instance."
#     123         " Please call it on the class type and make sure the return value is used."
#     124     )
# --> 125 return self.method(cls, *args, **kwargs)
#
# File /opt/anaconda3/envs/xfads/lib/python3.10/site-packages/pytorch_lightning/core/module.py:1581, in LightningModule.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#    1492 @_restricted_classmethod
#    1493 def load_from_checkpoint(
#    1494     cls,
#    (...)
#    1499     **kwargs: Any,
#    1500 ) -> Self:
#    1501     r"""Primary way of loading a model from a checkpoint. When Lightning saves a checkpoint it stores the arguments
#    1502     passed to ``__init__``  in the checkpoint under ``"hyper_parameters"``.
#    1503
#    (...)
#    1579
#    1580     """
# -> 1581     loaded = _load_from_checkpoint(
#    1582         cls,  # type: ignore[arg-type]
#    1583         checkpoint_path,
#    1584         map_location,
#    1585         hparams_file,
#    1586         strict,
#    1587         **kwargs,
#    1588     )
#    1589     return cast(Self, loaded)
#
# File /opt/anaconda3/envs/xfads/lib/python3.10/site-packages/pytorch_lightning/core/saving.py:91, in _load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#      89     return _load_state(cls, checkpoint, **kwargs)
#      90 if issubclass(cls, pl.LightningModule):
# ---> 91     model = _load_state(cls, checkpoint, strict=strict, **kwargs)
#      92     state_dict = checkpoint["state_dict"]
#      93     if not state_dict:
#
# File /opt/anaconda3/envs/xfads/lib/python3.10/site-packages/pytorch_lightning/core/saving.py:180, in _load_state(cls, checkpoint, strict, **cls_kwargs_new)
#     177     obj.on_load_checkpoint(checkpoint)
#     179 # load the state_dict on the model automatically
# --> 180 keys = obj.load_state_dict(checkpoint["state_dict"], strict=strict)
#     182 if not strict:
#     183     if keys.missing_keys:
#
# File /opt/anaconda3/envs/xfads/lib/python3.10/site-packages/torch/nn/modules/module.py:2153, in Module.load_state_dict(self, state_dict, strict, assign)
#    2148         error_msgs.insert(
#    2149             0, 'Missing key(s) in state_dict: {}. '.format(
#    2150                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2152 if len(error_msgs) > 0:
# -> 2153     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2154                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2155 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LightningNonlinearSSM:
# 	Missing key(s) in state_dict: "ssm.likelihood_pdf.log_R".

# %%
loss, z, stats = seq_vae.ssm(y_valid, cfg.n_samples)

n_ex = 10

fig, axs = plt.subplots(n_ex, 1, figsize=(5, 8))

[axs[i].plot(stats['m_f'][i, :, 0].detach().numpy(), color='red', alpha=0.4) for i in range(n_ex)]
[axs[i].plot(z_valid[i, :, 0].detach().numpy(), color='black', alpha=0.8) for i in range(n_ex)]

fig.show()

fig, axs = plt.subplots()
plot_utils.plot_two_d_vector_field(seq_vae.ssm.dynamics_mod.mean_fn, axs)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 loss, z, stats = seq_vae.ssm(y_valid, cfg.n_samples)
#       3 n_ex = 10
#       5 fig, axs = plt.subplots(n_ex, 1, figsize=(5, 8))
#
# NameError: name 'seq_vae' is not defined

# %%
loss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 loss
#
# NameError: name 'loss' is not defined

# %%
z.shape
# Out:
# torch.Size([500, 250, 2])

# %%
stats.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 stats.keys()
#
# NameError: name 'stats' is not defined

# %%
y_valid.shape
# Out:
# torch.Size([250, 250, 100])
